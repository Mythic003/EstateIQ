# %% [markdown]
# ## House Price India ##

# %% [markdown]
# Kaggle Link :- https://www.kaggle.com/datasets/mohamedafsal007/house-price-dataset-of-india

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_link = r"D:\MU\8th_Sem\Final_Sem_Project\EstateIQ\Data\Datasets\House_Price_India\House_Price_India.csv"
dataset = pd.read_csv(dataset_link)
dataset.head()
# Out:
#      Price          id  number of bedrooms  no._of_bathrooms  living area  \
# 0  2380000  6762810145                   5              2.50         3650
# 1  1400000  6762810635                   4              2.50         2920
# 2  1200000  6762810998                   5              2.75         2910
# 3   838000  6762812605                   4              2.50         3310
# 4   805000  6762812919                   3              2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Area of the basement  Built Year  \
# ...

# %%
dataset.columns
# Out:
# Index(['Price', 'id', 'number of bedrooms', 'no._of_bathrooms', 'living area',
#        'lot area', 'number of floors', 'waterfront present', 'number of views',
#        'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport'],
#       dtype='object')
